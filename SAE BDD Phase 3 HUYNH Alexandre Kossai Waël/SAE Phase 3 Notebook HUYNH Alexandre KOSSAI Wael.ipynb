# %% [markdown]
# # <center>SAE BDD - Phase 3</center>

# %% [markdown]
# # Sommaire
#
# ## I - Rapport
# - 1) Rapport sur les requêtes imposées
# - 2) Rapport sur les requêtes inventées
# </ul>
#
# ## II - Script
# - 1) Initialisation des tables
# - 2) Requêtes imposées
# - 3) Requêtes inventées
# - 4) Commandes de réinitialisations
# - 5) Script sous format texte
#
# ---

# %% [markdown]
# # I - Rapport

# %% [markdown]
# ## 1) Rapport sur les requêtes imposées
#
# - **Combien de classes de passagers différentes y avait-il à bord du Titanic ?**
#
# ---> Il y avait 3 classes de passagers différentes.<br><br>
#
# - **Combien de passagers y avait-il dans chaque classe?**
#
# ---> Il y avait 216 passagers en 1ère classe, 184 en 2ème classe et 491 en 3ème classe, ce qui équivaut bien à 891 passagers.<br><br>
#
# - **Combien de femmes et d'hommes y avait-il dans chaque classe?**
#
# ---> En 1ère classe, il y avait 94 femmes et 122 hommes, en 2ème classe 76 femmes et 108 hommes, en 3ème classe 144 femmes et 347 hommes.<br><br>
#
# - **Comptez le nombre et le pourcentage de survivants et de passagers morts.**
#
# ---> Après le nauffrage du Titanic, il y avait 549 passagers morts et 342 survivants, soit environ 62% de décédés et 38% survivants.<br><br>
#
# - **Visualiser la répartition des passagers survivants et morts par classe.**
#
# ---> A partir de la requête, on peut voir qu'il y avait:
#
# - 80 morts et 136 survivants en 1ère classe,
# - 97 morts et 87 survivants en 2ème classe,
# - 372 morts et 119 survivants en 3ème classe.<br>
# </ul>
# On remarque donc qu'il y a le plus de décès en 3ème classe (372 morts), où les passagers sont en théorie plutôt de classe populaire, et qu'il y a le plus de survivants en 1ère classe (136 survivants), où la population est plus aisée.<br>
# Cela peut-être en partie expliqué par le fait que les passagers de 1ère classes sont situés en haut du Titanic et ceux de la 3ème classe en bas.
# Il faut néanmoins tenir compte de la différence en terme de nombre de passagers dans chaque classe.<br>
#
#
# - **Visualiser la répartition des passagers survivants et des passagers décédés selon le sexe.**
#
# ---> On remarque qu'il y avait très peu de femmes décédés en 1ère et 2ème classe: seulement 3 femmes en 1ère classe et 6 en 2ème classe.<br>
#
# D'autre part, il y avait beaucoup plus de femmes qui ont survécu que d'hommes: 91 femmes en vie comparé à 45 hommes en 1ère classe, 70 femmes ont survécus comparé à 17 en 2ème classe et 72 femmes comparé à 47 hommes en 3ème classe.<br>
#
# Cela pouvait supposer que les femmes dans ces classes étaient prioritaires lors du sauvetage et de l'évacuation du Titanic.<br>
#
# On remarque qu'il y a le plus de mort en 3ème classe avec 300 hommes décédés.
#
# </ul>

# %% [markdown]
# ## 2) Rapport sur les requêtes inventées
#
# - **Donnez l'âge du passager le plus âgé.**
#
# ---> Le passager le plus âge a 80 ans.<br><br>
#
# - **Combien y'avait-il de mineurs parmi les passagers (strictement moins de 18 ans) ?**
#
# ---> Parmi les passagers, il y a 113 mineurs ayant dont moins de 18 ans.<br><br>
#
# - **Combien y'avait-il de femmes parmi les passagers ?**
#
# ---> Il y avait 314 passagères à bord du Titanic.<br><br>
#
# - **Combien y'avait-il de survivants au naufrage du Titanic ?**
#
# ---> Il y avait 342 survivants au naufrage du Titanic.<br><br>
#
# - **Combien y'avait-il de femmes mineures qui ont survécus au naufrage ?**
#
# ---> Il y avait 74 femmes mineures qui ont survécus.<br><br>
#
# - **A combien s'élève les profits réalisés à partir de la vente des tickets pour le voyage à bord du Titanic ?***
#
# ---> Au total, les bénéfices de la vente des tickets s'élève à environ 28693.95 £.<br><br>
#
# </ul>

# %% [markdown]
# # II - Script

# %%
# %load_ext sql

# %%
# %sql postgresql://12102253:091003608EG@aquabdd/postgres

# %% [markdown]
# ## 1) Initialisation des tables

# %%
# %%sql
# CREATE TABLE ticket(Name varchar(100) primary key, Pclass int, Ticket varchar(20),
#                     Fare float, Cabin varchar(20), Embarked varchar(1));
#
# CREATE TABLE passager(PassengerId int primary key, Name varchar(100), Sex varchar(6), Age float, SibSp int, Parch int,
#                       foreign key (Name) references ticket(Name));
#
# CREATE TABLE survivant(PassengerId int, Name varchar(100), Survived int,
#                        foreign key (PassengerId) references passager(passengerid),
#                        foreign key (Name) references ticket(name));
# Out:
#  * postgresql://user1:***@localhost/postgres
# (psycopg2.errors.DuplicateTable) ERREUR:  la relation « ticket » existe déjà
#
# [SQL: CREATE TABLE ticket(Name varchar(100) primary key, Pclass int, Ticket varchar(20),
#                     Fare float, Cabin varchar(20), Embarked varchar(1));]
# (Background on this error at: http://sqlalche.me/e/14/f405)

# %%
# %%sql
# \copy ticket from '/Users/Asus/Documents/ticket.txt'
# Out:
#  * postgresql://user1:***@localhost/postgres
# ---------------------------------------------------------------------------
# UniqueViolation                           Traceback (most recent call last)
# <ipython-input-5-f6b97dffca40> in <module>
# ----> 1 get_ipython().run_cell_magic('sql', '', "\\copy ticket from '/Users/Asus/Documents/ticket.txt'\n")
#
# E:\anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2397             with self.builtin_trap:
#    2398                 args = (magic_arg_s, cell)
# -> 2399                 result = fn(*args, **kwargs)
#    2400             return result
#    2401
#
# E:\anaconda3\lib\site-packages\decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# ...

# %%
# %%sql
# \copy passager from '/Users/Asus/Documents/passager.txt'
# Out:
#  * postgresql://user1:***@localhost/postgres
# 0 rows affected.
# []

# %%
# %%sql
# \copy survivant from '/Users/Asus/Documents/survivant.txt'
# Out:
#  * postgresql://user1:***@localhost/postgres
# 0 rows affected.
# []

# %%
# %%sql
# SELECT * from ticket;
# Out:
#  * postgresql://12102253:***@aquabdd/postgres
# 0 rows affected.
# []

# %%
# %%sql
# SELECT * from passager;
# Out:
#  * postgresql://user1:***@localhost/postgres
# 891 rows affected.
# [(1, 'Braund, Mr. Owen Harris', 'male', 22.0, 1, 0),
#  (2, 'Cumings, Mrs. John Bradley (Florence Briggs Thayer)', 'female', 38.0, 1, 0),
#  (3, 'Heikkinen, Miss. Laina', 'female', 26.0, 0, 0),
#  (4, 'Futrelle, Mrs. Jacques Heath (Lily May Peel)', 'female', 35.0, 1, 0),
#  (5, 'Allen, Mr. William Henry', 'male', 35.0, 0, 0),
#  (6, 'Moran, Mr. James', 'male', 0.0, 0, 0),
#  (7, 'McCarthy, Mr. Timothy J', 'male', 54.0, 0, 0),
#  (8, 'Palsson, Master. Gosta Leonard', 'male', 2.0, 3, 1),
#  (9, 'Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)', 'female', 27.0, 0, 2),
#  (10, 'Nasser, Mrs. Nicholas (Adele Achem)', 'female', 14.0, 1, 0),
#  (11, 'Sandstrom, Miss. Marguerite Rut', 'female', 4.0, 1, 1),
#  (12, 'Bonnell, Miss. Elizabeth', 'female', 58.0, 0, 0),
#  (13, 'Saundercock, Mr. William Henry', 'male', 20.0, 0, 0),
#  (14, 'Andersson, Mr. Anders Johan', 'male', 39.0, 1, 5),
# ...

# %%
# %%sql
# SELECT * from survivant;
# Out:
#  * postgresql://user1:***@localhost/postgres
# 891 rows affected.
# [(1, 'Braund, Mr. Owen Harris', 0),
#  (2, 'Cumings, Mrs. John Bradley (Florence Briggs Thayer)', 1),
#  (3, 'Heikkinen, Miss. Laina', 1),
#  (4, 'Futrelle, Mrs. Jacques Heath (Lily May Peel)', 1),
#  (5, 'Allen, Mr. William Henry', 0),
#  (6, 'Moran, Mr. James', 0),
#  (7, 'McCarthy, Mr. Timothy J', 0),
#  (8, 'Palsson, Master. Gosta Leonard', 0),
#  (9, 'Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)', 1),
#  (10, 'Nasser, Mrs. Nicholas (Adele Achem)', 1),
#  (11, 'Sandstrom, Miss. Marguerite Rut', 1),
#  (12, 'Bonnell, Miss. Elizabeth', 1),
#  (13, 'Saundercock, Mr. William Henry', 0),
#  (14, 'Andersson, Mr. Anders Johan', 0),
#  (15, 'Vestrom, Miss. Hulda Amanda Adolfina', 0),
#  (16, 'Hewlett, Mrs. (Mary D Kingcome) ', 1),
#  (17, 'Rice, Master. Eugene', 0),
#  (18, 'Williams, Mr. Charles Eugene', 1),
#  (19, 'Vander Planke, Mrs. Julius (Emelia Maria Vandemoortele)', 0),
# ...

# %% [markdown]
# ## 2) Requêtes imposées

# %% [markdown]
# - Combien de classes de passagers différentes y avait-il à bord du Titanic ?

# %%
# %%sql
# select count(*) as classes_de_passagers
#     from (select distinct pclass from ticket) as liste_classes;
# Out:
#  * postgresql://user1:***@localhost/postgres
# 1 rows affected.
# [(3,)]

# %% [markdown]
# ---
# - Combien de passagers y avait-il dans chaque classe?

# %%
# %%sql
# select pclass, count(*) as passagers
#     from ticket
#     group by pclass
#     order by pclass;
# Out:
#  * postgresql://user1:***@localhost/postgres
# 3 rows affected.
# [(1, 216), (2, 184), (3, 491)]

# %% [markdown]
# ---
# - Combien de femmes et d'hommes y avait-il dans chaque classe?

# %%
# %%sql
# select ticket.pclass, passager.sex, count(*) as passagers
#     from ticket natural join passager
#     group by ticket.pclass,passager.sex
#     order by ticket.pclass,passager.sex;
# Out:
#  * postgresql://user1:***@localhost/postgres
# 6 rows affected.
# [(1, 'female', 94),
#  (1, 'male', 122),
#  (2, 'female', 76),
#  (2, 'male', 108),
#  (3, 'female', 144),
#  (3, 'male', 347)]

# %% [markdown]
# ---
# - Comptez le nombre et le pourcentage de survivants et de passagers
# morts.

# %%
# %%sql
# select survivant.survived, count(*) as passagers, (count(*) * 100 / (select count(*) from survivant)) as pourcentage
#     from survivant
#     group by survived;
# Out:
#  * postgresql://user1:***@localhost/postgres
# 2 rows affected.
# [(0, 549, 61), (1, 342, 38)]

# %% [markdown]
# ---
# - Visualiser la répartition des passagers survivants et morts par classe

# %%
# %%sql
# select ticket.pclass, survivant.survived, count(*) as passagers
#     from ticket natural join survivant
#     group by pclass, survived
#     order by pclass, survived;
# Out:
#  * postgresql://user1:***@localhost/postgres
# 6 rows affected.
# [(1, 0, 80), (1, 1, 136), (2, 0, 97), (2, 1, 87), (3, 0, 372), (3, 1, 119)]

# %% [markdown]
# ---
# - Visualiser la répartition des passagers survivants et des passagers
# décédés selon le sexe

# %%
# %%sql
# select ticket.pclass, survivant.survived, passager.sex, count(*) as passagers
#     from ticket natural join passager natural join survivant
#     group by pclass, survived, sex
#     order by pclass;
# Out:
#  * postgresql://user1:***@localhost/postgres
# 12 rows affected.
# [(1, 0, 'female', 3),
#  (1, 0, 'male', 77),
#  (1, 1, 'female', 91),
#  (1, 1, 'male', 45),
#  (2, 0, 'female', 6),
#  (2, 0, 'male', 91),
#  (2, 1, 'female', 70),
#  (2, 1, 'male', 17),
#  (3, 0, 'female', 72),
#  (3, 0, 'male', 300),
#  (3, 1, 'female', 72),
#  (3, 1, 'male', 47)]

# %% [markdown]
# ## 3) Requêtes inventés

# %% [markdown]
# - Donnez l'identifiant et le nom de tous les passagers survivants.

# %%
# %%sql
# select passengerid,name
#     from survivant
#     where survived=1;
# Out:
#  * postgresql://user1:***@localhost/postgres
# 342 rows affected.
# [(2, 'Cumings, Mrs. John Bradley (Florence Briggs Thayer)'),
#  (3, 'Heikkinen, Miss. Laina'),
#  (4, 'Futrelle, Mrs. Jacques Heath (Lily May Peel)'),
#  (9, 'Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)'),
#  (10, 'Nasser, Mrs. Nicholas (Adele Achem)'),
#  (11, 'Sandstrom, Miss. Marguerite Rut'),
#  (12, 'Bonnell, Miss. Elizabeth'),
#  (16, 'Hewlett, Mrs. (Mary D Kingcome) '),
#  (18, 'Williams, Mr. Charles Eugene'),
#  (20, 'Masselmani, Mrs. Fatima'),
#  (22, 'Beesley, Mr. Lawrence'),
#  (23, 'McGowan, Miss. Anna "Annie"'),
#  (24, 'Sloper, Mr. William Thompson'),
#  (26, 'Asplund, Mrs. Carl Oscar (Selma Augusta Emilia Johansson)'),
#  (29, 'O\'Dwyer, Miss. Ellen "Nellie"'),
#  (32, 'Spencer, Mrs. William Augustus (Marie Eugenie)'),
#  (33, 'Glynn, Miss. Mary Agatha'),
#  (37, 'Mamee, Mr. Hanna'),
#  (40, 'Nicola-Yarred, Miss. Jamila'),
#  (44, 'Laroche, Miss. Simonne Marie Anne Andree'),
# ...

# %% [markdown]
# ---
# - Donnez le nom, le ticket et l'âge des hommes agés de plus ou égal 50 ans qui ont fait embarcation depuis le port de Cherbourg (C).

# %%
# %%sql
# select ticket.name,ticket.ticket, passager.age
#     from ticket natural join passager
#     where ticket.embarked='C'and passager.age>=50 and passager.sex='male';
# Out:
#  * postgresql://user1:***@localhost/postgres
# 10 rows affected.
# [('Ostby, Mr. Engelhart Cornelius', '113509', 65.0),
#  ('Goldschmidt, Mr. George B', 'PC 17754', 71.0),
#  ('Williams, Mr. Charles Duane', 'PC 17597', 51.0),
#  ('Smith, Mr. James Clinch', '17764', 56.0),
#  ('Kent, Mr. Edward Austin', '11771', 58.0),
#  ('Artagaveytia, Mr. Ramon', 'PC 17609', 71.0),
#  ('Douglas, Mr. Walter Donald', 'PC 17761', 50.0),
#  ('Frolicher-Stehli, Mr. Maxmillian', '13567', 60.0),
#  ('Simonius-Blumer, Col. Oberst Alfons', '13213', 56.0),
#  ('Newell, Mr. Arthur Webster', '35273', 58.0)]

# %% [markdown]
# ---
# - Donnez l'âge du passager le plus âgé.

# %%
# %%sql
# select max(age) as age
#     from passager;
# Out:
#  * postgresql://user1:***@localhost/postgres
# 1 rows affected.
# [(80.0,)]

# %% [markdown]
# ---
# - Combien y'avait-il de mineurs parmi les passagers (strictement moins de 18 ans) ?

# %%
# %%sql
# --Les passagers dont l'age est inconnu ont un age de 0.0
# select count(*) as mineurs
#     from passager
#     where age>0.0 and age<18;
# Out:
#  * postgresql://user1:***@localhost/postgres
# 1 rows affected.
# [(113,)]

# %% [markdown]
# ---
# - Combien y'avait-il de femmes parmi les passagers ?

# %%
# %%sql
# select sex, count(*) as passagers
#     from passager
#     where sex='female'
#     group by sex;
# Out:
#  * postgresql://user1:***@localhost/postgres
# 1 rows affected.
# [('female', 314)]

# %% [markdown]
# ---
# - Combien y'avait-il de survivants au naufrage du Titanic ?

# %%
# %%sql
# select survived, count(*) as passagers
#     from survivant
#     where survived=1
#     group by survived;
# Out:
#  * postgresql://user1:***@localhost/postgres
# 1 rows affected.
# [(1, 342)]

# %% [markdown]
# ---
# - Combien y'avait-il de femmes mineures qui ont survécus au naufrage ?

# %%
# %%sql
# select count(*) as mineures_survivantes
#     from passager natural join ticket natural join survivant
#     where survived=1 and sex='female' and age<18;
# Out:
#  * postgresql://user1:***@localhost/postgres
# 1 rows affected.
# [(74,)]

# %% [markdown]
# ---
# - A combien s'élève les profits réalisés à partir de la vente des tickets pour le voyage à bord du Titanic ?

# %%
# %%sql
# select sum(fare) as benefices
#     from ticket;
# Out:
#  * postgresql://user1:***@localhost/postgres
# 1 rows affected.
# [(28693.9493,)]

# %% [markdown]
# ## 4) Commandes de réinitialisations

# %%
# %%sql
# delete from survivant;
# delete from passager;
# delete from ticket;

# %%
# %%sql
# drop table survivant;
# drop table passager;
# drop table ticket;

# %% [markdown]
# ## 5) Script sous format texte

# %% [raw]
# -- Initialisation
#
# CREATE TABLE ticket(Name varchar(100) primary key, Pclass int, Ticket varchar(20),
#                     Fare float, Cabin varchar(20), Embarked varchar(1));
#
# CREATE TABLE passager(PassengerId int primary key, Name varchar(100), Sex varchar(6), Age float, SibSp int, Parch int,
#                       foreign key (Name) references ticket(Name));
#
# CREATE TABLE survivant(PassengerId int, Name varchar(100), Survived int,
#                        foreign key (PassengerId) references passager(passengerid),
#                        foreign key (Name) references ticket(name));
#
# \copy ticket from '/Users/Asus/Documents/ticket.txt'
# \copy passager from '/Users/Asus/Documents/passager.txt'
# \copy survivant from '/Users/Asus/Documents/survivant.txt'
#
# SELECT * from ticket;
# SELECT * from passager;
# SELECT * from survivant;
#
# -- Requetes imposées
#
# -- Combien de classes de passagers différentes y avait-il à bord du Titanic ?
#
# select count(*) as classes_de_passagers
#     from (select distinct pclass from ticket) as liste_classes;
#
# -- Combien de passagers y avait-il dans chaque classe?
#
# select pclass, count(*) as passagers
#     from ticket
#     group by pclass
#     order by pclass;
#
# -- Combien de femmes et d'hommes y avait-il dans chaque classe?
#
# select ticket.pclass, passager.sex, count(*) as passagers
#     from ticket natural join passager
#     group by ticket.pclass,passager.sex
#     order by ticket.pclass,passager.sex;
#
# -- Comptez le nombre et le pourcentage de survivants et de passagers morts.
#
# select survivant.survived, count(*) as passagers, (count(*) * 100 / (select count(*) from survivant)) as pourcentage
#     from survivant
#     group by survived;
#
# -- Visualiser la répartition des passagers survivants et morts par classe
#
# select ticket.pclass, survivant.survived, count(*) as passagers
#     from ticket natural join survivant
#     group by pclass, survived
#     order by pclass, survived;
#
# -- Visualiser la répartition des passagers survivants et des passagers décédés selon le sexe
#
# select ticket.pclass, survivant.survived, passager.sex, count(*) as passagers
#     from ticket natural join passager natural join survivant
#     group by pclass, survived, sex
#     order by pclass;
#
# -- Requetes inventées
#
# -- Donnez l'identifiant et le nom de tous les passagers survivants.
#
# select passengerid,name
#     from survivant
#     where survived=1;
#
# -- Donnez le nom, le ticket et l'âge des hommes agés de plus ou égal 50 ans qui ont fait embarcation depuis le port de Cherbourg (C).
#
# select ticket.name,ticket.ticket, passager.age
#     from ticket natural join passager
#     where ticket.embarked='C'and passager.age>=50 and passager.sex='male';
#
# -- Donnez l'âge du passager le plus âgé.
#
# select max(age) as age
#     from passager;
#
# -- Combien y'avait-il de mineurs parmi les passagers (strictement moins de 18 ans) ?
#
# --Les passagers dont l'age est inconnu ont un age de 0.0
# select count(*) as mineurs
#     from passager
#     where age>0.0 and age<18;
#
# -- Combien y'avait-il de femmes parmi les passagers ?
#
# select sex, count(*) as passagers
#     from passager
#     where sex='female'
#     group by sex;
#
# -- Combien y'avait-il de survivants au naufrage du Titanic ?
#
# select survived, count(*) as passagers
#     from survivant
#     where survived=1
#     group by survived;
#
# -- Combien y'avait-il de femmes mineures qui ont survécus au naufrage ?
#
# select count(*) as mineures_survivantes
#     from passager natural join ticket natural join survivant
#     where survived=1 and sex='female' and age<18;
#
# -- A combien s'élève les profits réalisés à partir de la vente des tickets pour le voyage à bord du Titanic ?
#
# select sum(fare) as benefices
#     from ticket;
#
# --Commandes de réinitialisations
#
# --delete from survivant;
# --delete from passager;
# --delete from ticket;
#
# --drop table survivant;
# --drop table passager;
# --drop table ticket;
